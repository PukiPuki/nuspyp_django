# %%
from tesserwrap import Tesseract
from wand.image import Image as WImage
from PIL import Image
from io import BytesIO
from io import StringIO
import numpy as np
import matplotlib.pyplot as pyplot
% matplotlib inline

with WImage(filename='source.pdf[1]', resolution=500) as img:
    jpeg_bin = img.make_blob('jpeg')

stream = BytesIO(jpeg_bin)
img = Image.open(stream)
print(img.size)
tr = Tesseract()
tr.ocr_image(img)
tr.get_text()
# Out:
# (4133, 5846)
# ...

# %%
tr.get_textlines()
# Out:
# [Item(value=b'2\n', confidence=99.609375, box=(2037, 319, 2073, 376)),
#  Item(value=b'PART I\n', confidence=94.26512145996094, box=(1919, 568, 2195, 624)),
#  Item(value=b'This part of the examination paper contains five short-answer questions on pages 2 to 3.\n', confidence=88.79397583007812, box=(495, 666, 3616, 749)),
#  Item(value=b'Answer ALL questions.\n', confidence=88.29234313964844, box=(494, 768, 1292, 843)),
#  Item(value=b'1. Consider an isolated spherical conductor S of radius R carrying a net charge Q.\n', confidence=88.74685668945312, box=(503, 963, 3251, 1043)),
#  Item(value=b'(a) Calculate the total work W needed to assemble this charge Q by bringing in\xef\xac\x81nitesimal\n', confidence=89.34300994873047, box=(622, 1057, 3621, 1140)),
#  Item(value=b'charges a\xe2\x80\x99q from in\xef\xac\x81nity and depositing them on the surface of S. [2]\n', confidence=90.07791137695312, box=(746, 1153, 3600, 1236)),
# ...

# %%
import matplotlib.pyplot as plt
% matplotlib inline

npimg = np.array(img)
np.where(npimg,255,122)
pyplot.imshow(npimg)

# %%
npimg = np.array(img)
print(npimg.shape)
npimg2 = np.mean(npimg, axis=2)
npimg3 = np.where(npimg2>200, 255, 0)
plt.imshow(npimg2)
# Out:
# (3507, 2480, 3)

# %%
plt.figure(num=None, figsize=(8, 6), dpi=160, facecolor='w', edgecolor='k')
plt.imshow(npimg3)

# %%
npimg3
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]])
